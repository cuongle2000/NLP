# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# plt.style.available
# plt.style.use('seaborn')

# %%
plt.plot();

# %%
x = [1, 2, 3, 4]
y = [10, 8, 11, 9]
plt.plot(x, y, color="red");

# %%
x = np.linspace(0, 100, 1000)
plt.plot(x, np.sin(x), color="blue", linestyle="dotted", label="sin(x)")
plt.plot(x, np.cos(x), color="red", label="cos(x)")
plt.title("Sin(x) and Cos(x)")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.xlim([0, 10])
plt.ylim([-1, 1])
plt.legend()

# %%
x = np.linspace(-5, 5, 1000)
y = np.exp(x)
plt.plot(x, y, color="red", label="e^x")
y2 = x * x 
plt.plot(x, y2, color="blue", label="x^2")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("x^2 and e^x")
plt.legend()

# %%
x = np.linspace(-5, 5, 10)
sigmoid = np.exp(x) / (np.exp(x) + 1)
plt.plot(x, sigmoid, 'ro')
plt.grid()

# %%
names = ["groud_a", "groud_b", "group_c"]
values = [1, 10, 100]
plt.figure(figsize=(9, 3))
plt.subplot(131)
plt.bar(names, values)

plt.subplot(132)
plt.scatter(names, values)

plt.subplot(133)
plt.plot(names, values)

plt.suptitle("Categorical Plotting")
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %%
plt.hist(values, 50);

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(1000)

n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
